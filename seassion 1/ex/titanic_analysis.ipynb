# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('titanic.csv')
survived = dataset[dataset['Survived']==1]
survived = dataset[dataset['Survived']==2]

# %%
dataset
# Out:
#      Survived  Pclass  Sex   Age  Siblings/Spouses Aboard  \
# 0           0       3    0  14.0                        0
# 1           0       3    0  31.0                        1
# 2           0       3    0   8.0                        3
# 3           0       3    0  18.0                        2
# 4           0       3    0  40.0                        1
# ..        ...     ...  ...   ...                      ...
# 882         1       3    1  32.0                        0
# 883         1       1    1  29.0                        0
# 884         1       1    1  51.0                        0
# 885         1       3    1   4.0                        1
# 886         1       1    1  26.0                        0
#
#      Parents/Children Aboard     Fare
# 0                          0   7.8542
# 1                          0  18.0000
# 2                          1  21.0750
# 3                          0  18.0000
# 4                          0   9.4750
# ...

# %%
dataset.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Sex                      887 non-null    int64
#  3   Age                      887 non-null    float64
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
# dtypes: float64(2), int64(5)
# memory usage: 48.6 KB

# %%
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  Siblings/Spouses Aboard  \
# 0         0       3    0  14.0                        0
# 1         0       3    0  31.0                        1
# 2         0       3    0   8.0                        3
# 3         0       3    0  18.0                        2
# 4         0       3    0  40.0                        1
#
#    Parents/Children Aboard     Fare
# 0                        0   7.8542
# 1                        0  18.0000
# 2                        1  21.0750
# 3                        0  18.0000
# 4                        0   9.4750

# %%
dataset.tail()
# Out:
#      Survived  Pclass  Sex   Age  Siblings/Spouses Aboard  \
# 882         1       3    1  32.0                        0
# 883         1       1    1  29.0                        0
# 884         1       1    1  51.0                        0
# 885         1       3    1   4.0                        1
# 886         1       1    1  26.0                        0
#
#      Parents/Children Aboard     Fare
# 882                        0  56.4958
# 883                        0  29.7000
# 884                        0  26.5500
# 885                        1  11.1333
# 886                        0  30.0000

# %%
dataset['Sex'].value_counts()
# Out:
# Sex
# 1    573
# 0    314
# Name: count, dtype: int64

# %%
dataset.describe()
# Out:
#          Survived      Pclass         Sex         Age  \
# count  887.000000  887.000000  887.000000  887.000000
# mean     0.385569    2.305524    0.645998   29.471443
# std      0.487004    0.836662    0.478480   14.121908
# min      0.000000    1.000000    0.000000    0.420000
# 25%      0.000000    2.000000    0.000000   20.250000
# 50%      0.000000    3.000000    1.000000   28.000000
# 75%      1.000000    3.000000    1.000000   38.000000
# max      1.000000    3.000000    1.000000   80.000000
#
#        Siblings/Spouses Aboard  Parents/Children Aboard       Fare
# count               887.000000               887.000000  887.00000
# mean                  0.525366                 0.383315   32.30542
# std                   1.104669                 0.807466   49.78204
# min                   0.000000                 0.000000    0.00000
# 25%                   0.000000                 0.000000    7.92500
# 50%                   0.000000                 0.000000   14.45420
# ...

# %%
plt.plot(dataset['Sex'] , dataset['Age'] ,'o')
plt.xlabel('Sex',fontsize=12,color='red')
plt.ylabel('Age',fontsize=12,color='blue')
plt.show()

# %%
dataset.hist()
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(dataset, hue='Sex')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Survived", data=dataset, palette="coolwarm",hue='Pclass')
plt.title("Survival Count")
plt.xticks([0, 1], ["Non-Survivors", "Survivors"])
plt.show()
